# %%
# ex01
numbers = [2,5,6,76,44,88]
print(numbers[0])
print(numbers[-1])
print(numbers[-3])
# Out:
# 2
# 88
# 76

# %%
# ex02
a = [10,20,30,40,50]
a.append(60)
print(a)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
a = [10,20,30,40,50]
a.insert(1,15)
print(a)
# Out:
# [10, 15, 20, 30, 40, 50]

# %%
a = [10,20,30,40,50]
a.remove(40)
print(a)
# Out:
# [10, 20, 30, 50]

# %%
movie_list = ["Inception", "Interstellar", "The Dark Knight", "Tenet","Jai Bhim"]
print(len(movie_list))
# Out:
# 5
